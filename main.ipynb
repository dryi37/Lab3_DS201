# %% [markdown]
# ## Bài 1

# %%
# %run train.py -c config/lstm.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
#
# Epoch 1/30
# train: 100%|██████████| 358/358 [00:07<00:00, 44.95it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 125.04it/s]
# Train Loss: 0.8541 | Train F1: 0.5956
# Dev Loss:   0.8431 | Dev F1:   0.6122
# [INFO] New best model saved! F1 = 0.6122
#
# Epoch 2/30
# train: 100%|██████████| 358/358 [00:07<00:00, 47.55it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 133.29it/s]
# Train Loss: 0.8451 | Train F1: 0.5958
# Dev Loss:   0.8458 | Dev F1:   0.6122
#
# Epoch 3/30
# train: 100%|██████████| 358/358 [00:07<00:00, 47.98it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 141.37it/s]
# Train Loss: 0.8458 | Train F1: 0.5958
# Dev Loss:   0.8399 | Dev F1:   0.6122
#
# Epoch 4/30
# train: 100%|██████████| 358/358 [00:07<00:00, 47.56it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 129.66it/s]
# Train Loss: 0.8512 | Train F1: 0.5958
# Dev Loss:   0.8632 | Dev F1:   0.6122
#
# Epoch 5/30
# train: 100%|██████████| 358/358 [00:07<00:00, 49.25it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 138.50it/s]
# Train Loss: 0.8444 | Train F1: 0.5958
# Dev Loss:   0.8462 | Dev F1:   0.6122
#
# Epoch 6/30
# train: 100%|██████████| 358/358 [00:07<00:00, 47.88it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 142.40it/s]
# Train Loss: 0.8469 | Train F1: 0.5958
# Dev Loss:   0.8425 | Dev F1:   0.6122
#
# [INFO] Early stopping! Best F1 = 0.6122

# %%
# %run test.py -c config/lstm.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
# D:\DS\ds201\TH\23520781_lab3\test.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(cfg["train"]["save_path"], map_location=device)
# Test F1: 0.6071775258751805
#
#
#                   precision    recall  f1-score   support
#
#         facility       0.00      0.00      0.00       145
#         lecturer       0.72      1.00      0.84      2290
#           others       0.00      0.00      0.00       159
# training_program       0.00      0.00      0.00       572
#
#         accuracy                           0.72      3166
#        macro avg       0.18      0.25      0.21      3166
#     weighted avg       0.52      0.72      0.61      3166
# d:\DS\py312env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\DS\py312env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\DS\py312env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## Bài 2

# %%
# %run train.py -c config/gru.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
#
# Epoch 1/30
# train: 100%|██████████| 358/358 [00:07<00:00, 46.95it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 113.71it/s]
# Train Loss: 0.6449 | Train F1: 0.7276
# Dev Loss:   0.4524 | Dev F1:   0.8126
# [INFO] New best model saved! F1 = 0.8126
#
# Epoch 2/30
# train: 100%|██████████| 358/358 [00:07<00:00, 48.44it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 153.95it/s]
# Train Loss: 0.4143 | Train F1: 0.8373
# Dev Loss:   0.3951 | Dev F1:   0.8579
# [INFO] New best model saved! F1 = 0.8579
#
# Epoch 3/30
# train: 100%|██████████| 358/358 [00:07<00:00, 50.46it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 138.50it/s]
# Train Loss: 0.3685 | Train F1: 0.8670
# Dev Loss:   0.3586 | Dev F1:   0.8740
# [INFO] New best model saved! F1 = 0.8740
#
# Epoch 4/30
# train: 100%|██████████| 358/358 [00:07<00:00, 50.19it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 133.99it/s]
# Train Loss: 0.3585 | Train F1: 0.8679
# Dev Loss:   0.3544 | Dev F1:   0.8725
#
# Epoch 5/30
# train: 100%|██████████| 358/358 [00:07<00:00, 49.36it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 140.78it/s]
# Train Loss: 0.3256 | Train F1: 0.8843
# Dev Loss:   0.3472 | Dev F1:   0.8729
#
# Epoch 6/30
# train: 100%|██████████| 358/358 [00:07<00:00, 49.72it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 126.27it/s]
# Train Loss: 0.3022 | Train F1: 0.8933
# Dev Loss:   0.3423 | Dev F1:   0.8836
# [INFO] New best model saved! F1 = 0.8836
#
# Epoch 7/30
# train: 100%|██████████| 358/358 [00:06<00:00, 51.25it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 128.86it/s]
# Train Loss: 0.2804 | Train F1: 0.9053
# Dev Loss:   0.3844 | Dev F1:   0.8545
#
# Epoch 8/30
# train: 100%|██████████| 358/358 [00:06<00:00, 53.87it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 128.77it/s]
# Train Loss: 0.2694 | Train F1: 0.9066
# Dev Loss:   0.3602 | Dev F1:   0.8817
#
# Epoch 9/30
# train: 100%|██████████| 358/358 [00:06<00:00, 52.84it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 133.87it/s]
# Train Loss: 0.2494 | Train F1: 0.9136
# Dev Loss:   0.3749 | Dev F1:   0.8738
#
# Epoch 10/30
# train: 100%|██████████| 358/358 [00:07<00:00, 50.17it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 139.66it/s]
# Train Loss: 0.2367 | Train F1: 0.9202
# Dev Loss:   0.4023 | Dev F1:   0.8678
#
# Epoch 11/30
# train: 100%|██████████| 358/358 [00:06<00:00, 51.56it/s]
# eval: 100%|██████████| 50/50 [00:00<00:00, 152.96it/s]
# Train Loss: 0.2288 | Train F1: 0.9220
# Dev Loss:   0.3797 | Dev F1:   0.8695
#
# [INFO] Early stopping! Best F1 = 0.8836

# %%
# %run test.py -c config/gru.yaml
# Out:
# D:\DS\ds201\TH\23520781_lab3\test.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(cfg["train"]["save_path"], map_location=device)
# Vocab size: 1525
# Num labels: 4
# Test F1: 0.6071775258751805
#
#
#                   precision    recall  f1-score   support
#
#         facility       0.00      0.00      0.00       145
#         lecturer       0.72      1.00      0.84      2290
#           others       0.00      0.00      0.00       159
# training_program       0.00      0.00      0.00       572
#
#         accuracy                           0.72      3166
#        macro avg       0.18      0.25      0.21      3166
#     weighted avg       0.52      0.72      0.61      3166
# d:\DS\py312env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\DS\py312env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\DS\py312env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## Bài 3

# %%
# %run train_ner.py -c config/bilstm_ner.yaml
# Out:
# Vocab size: 5243
# Num labels: 20
#
# Epoch 1/30
# train: 100%|██████████| 158/158 [00:11<00:00, 13.67it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.13it/s]
# Train Loss: 1.0312 | Train F1: 0.0023
# Dev   Loss: 0.9544 | Dev   F1: 0.0275
# [SAVE] Best model saved, F1 = 0.0275
#
# Epoch 2/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.19it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 45.60it/s]
# Train Loss: 0.4229 | Train F1: 0.5117
# Dev   Loss: 0.2682 | Dev   F1: 0.7134
# [SAVE] Best model saved, F1 = 0.7134
#
# Epoch 3/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.06it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.68it/s]
# Train Loss: 0.1768 | Train F1: 0.7983
# Dev   Loss: 0.2013 | Dev   F1: 0.8097
# [SAVE] Best model saved, F1 = 0.8097
#
# Epoch 4/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.57it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.23it/s]
# Train Loss: 0.1264 | Train F1: 0.8638
# Dev   Loss: 0.1765 | Dev   F1: 0.8260
# [SAVE] Best model saved, F1 = 0.8260
#
# Epoch 5/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.03it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.62it/s]
# Train Loss: 0.1093 | Train F1: 0.8806
# Dev   Loss: 0.1656 | Dev   F1: 0.8487
# [SAVE] Best model saved, F1 = 0.8487
#
# Epoch 6/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.38it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.15it/s]
# Train Loss: 0.0952 | Train F1: 0.8924
# Dev   Loss: 0.1777 | Dev   F1: 0.8418
#
# Epoch 7/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.44it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.98it/s]
# Train Loss: 0.0898 | Train F1: 0.8960
# Dev   Loss: 0.1612 | Dev   F1: 0.8591
# [SAVE] Best model saved, F1 = 0.8591
#
# Epoch 8/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.68it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 53.02it/s]
# Train Loss: 0.0823 | Train F1: 0.9037
# Dev   Loss: 0.1675 | Dev   F1: 0.8513
#
# Epoch 9/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.98it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.34it/s]
# Train Loss: 0.0767 | Train F1: 0.9118
# Dev   Loss: 0.1558 | Dev   F1: 0.8566
#
# Epoch 10/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.99it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 55.04it/s]
# Train Loss: 0.0708 | Train F1: 0.9140
# Dev   Loss: 0.2045 | Dev   F1: 0.8470
#
# Epoch 11/30
# train: 100%|██████████| 158/158 [00:10<00:00, 15.17it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 52.86it/s]
# Train Loss: 0.0700 | Train F1: 0.9168
# Dev   Loss: 0.1420 | Dev   F1: 0.8741
# [SAVE] Best model saved, F1 = 0.8741
#
# Epoch 12/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.67it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.05it/s]
# Train Loss: 0.0652 | Train F1: 0.9183
# Dev   Loss: 0.1649 | Dev   F1: 0.8587
#
# Epoch 13/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.26it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 49.50it/s]
# Train Loss: 0.0616 | Train F1: 0.9257
# Dev   Loss: 0.1679 | Dev   F1: 0.8595
#
# Epoch 14/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.73it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.38it/s]
# Train Loss: 0.0602 | Train F1: 0.9272
# Dev   Loss: 0.1313 | Dev   F1: 0.8763
# [SAVE] Best model saved, F1 = 0.8763
#
# Epoch 15/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.39it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.96it/s]
# Train Loss: 0.0541 | Train F1: 0.9370
# Dev   Loss: 0.1909 | Dev   F1: 0.8713
#
# Epoch 16/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.20it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 45.39it/s]
# Train Loss: 0.0507 | Train F1: 0.9370
# Dev   Loss: 0.1600 | Dev   F1: 0.8719
#
# Epoch 17/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.01it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 49.94it/s]
# Train Loss: 0.0476 | Train F1: 0.9397
# Dev   Loss: 0.1538 | Dev   F1: 0.8835
# [SAVE] Best model saved, F1 = 0.8835
#
# Epoch 18/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.59it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 52.11it/s]
# Train Loss: 0.0450 | Train F1: 0.9470
# Dev   Loss: 0.1698 | Dev   F1: 0.8555
#
# Epoch 19/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.32it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 49.13it/s]
# Train Loss: 0.0466 | Train F1: 0.9435
# Dev   Loss: 0.1461 | Dev   F1: 0.8877
# [SAVE] Best model saved, F1 = 0.8877
#
# Epoch 20/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.72it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 53.01it/s]
# Train Loss: 0.0428 | Train F1: 0.9479
# Dev   Loss: 0.1420 | Dev   F1: 0.8886
# [SAVE] Best model saved, F1 = 0.8886
#
# Epoch 21/30
# train: 100%|██████████| 158/158 [00:11<00:00, 13.71it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.24it/s]
# Train Loss: 0.0426 | Train F1: 0.9532
# Dev   Loss: 0.1727 | Dev   F1: 0.8795
#
# Epoch 22/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.40it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 50.15it/s]
# Train Loss: 0.0391 | Train F1: 0.9529
# Dev   Loss: 0.1316 | Dev   F1: 0.8883
#
# Epoch 23/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.15it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 52.91it/s]
# Train Loss: 0.0405 | Train F1: 0.9551
# Dev   Loss: 0.1491 | Dev   F1: 0.8951
# [SAVE] Best model saved, F1 = 0.8951
#
# Epoch 24/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.83it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.52it/s]
# Train Loss: 0.0363 | Train F1: 0.9592
# Dev   Loss: 0.1429 | Dev   F1: 0.8902
#
# Epoch 25/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.51it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 51.81it/s]
# Train Loss: 0.0382 | Train F1: 0.9570
# Dev   Loss: 0.1516 | Dev   F1: 0.8674
#
# Epoch 26/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.57it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.88it/s]
# Train Loss: 0.0362 | Train F1: 0.9604
# Dev   Loss: 0.1482 | Dev   F1: 0.8822
#
# Epoch 27/30
# train: 100%|██████████| 158/158 [00:10<00:00, 14.52it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.08it/s]
# Train Loss: 0.0359 | Train F1: 0.9577
# Dev   Loss: 0.1642 | Dev   F1: 0.8858
#
# Epoch 28/30
# train: 100%|██████████| 158/158 [00:11<00:00, 14.18it/s]
# eval: 100%|██████████| 63/63 [00:01<00:00, 48.62it/s]
# Train Loss: 0.0342 | Train F1: 0.9593
# Dev   Loss: 0.1319 | Dev   F1: 0.8934
#
# [STOP] Early stopping triggered!
# Best F1 = 0.8951

# %%
# %run test_ner.py
# Out:
# Device: cuda
# Vocab size: 5243
# Num labels: 20
# D:\DS\ds201\TH\23520781_lab3\test_ner.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(cfg["train"]["save_path"], map_location=device)
# Test F1: 0.8897
#
#                      precision    recall  f1-score   support
#
#                 AGE       0.93      0.94      0.94       582
#                DATE       0.95      0.97      0.96      1654
#              GENDER       0.91      0.95      0.93       462
#                 JOB       0.47      0.46      0.46       173
#            LOCATION       0.92      0.87      0.90      4441
#                NAME       0.78      0.61      0.69       318
#        ORGANIZATION       0.82      0.75      0.79       771
#          PATIENT_ID       0.96      0.96      0.96      2005
# SYMPTOM_AND_DISEASE       0.83      0.76      0.79      1136
#      TRANSPORTATION       0.86      0.83      0.85       193
#
#           micro avg       0.90      0.88      0.89     11735
#           macro avg       0.84      0.81      0.82     11735
#        weighted avg       0.90      0.88      0.89     11735
