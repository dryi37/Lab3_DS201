# %% [markdown]
# ## Bài 1

# %%
# %run train.py -c config/lstm.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
#
# Epoch 1/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 93.67it/s]
# Train Loss: 0.8211 | Train F1: 0.2246
# Dev Loss:   0.6287 | Dev F1:   0.2105
# [INFO] New best model saved! F1 = 0.2105
#
# Epoch 2/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 95.12it/s]
# Train Loss: 0.5829 | Train F1: 0.3887
# Dev Loss:   0.5133 | Dev F1:   0.4928
# [INFO] New best model saved! F1 = 0.4928
#
# Epoch 3/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 88.08it/s]
# Train Loss: 0.4918 | Train F1: 0.5543
# Dev Loss:   0.4537 | Dev F1:   0.5819
# [INFO] New best model saved! F1 = 0.5819
#
# Epoch 4/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 79.61it/s]
# Train Loss: 0.4470 | Train F1: 0.5976
# Dev Loss:   0.4454 | Dev F1:   0.5819
#
# Epoch 5/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 95.96it/s]
# Train Loss: 0.4277 | Train F1: 0.6114
# Dev Loss:   0.4333 | Dev F1:   0.5835
# [INFO] New best model saved! F1 = 0.5835
#
# Epoch 6/30
# ...

# %%
# %run test.py -c config/lstm.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
# D:\DS\ds201\TH\23520781_lab3\test.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# ## Bài 2

# %%
# %run train.py -c config/gru.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
#
# Epoch 1/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 101.35it/s]
# Train Loss: 0.8038 | Train F1: 0.2750
# Dev Loss:   0.5822 | Dev F1:   0.3636
# [INFO] New best model saved! F1 = 0.3636
#
# Epoch 2/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 92.27it/s]
# Train Loss: 0.5102 | Train F1: 0.5281
# Dev Loss:   0.4484 | Dev F1:   0.5943
# [INFO] New best model saved! F1 = 0.5943
#
# Epoch 3/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 70.31it/s]
# Train Loss: 0.4190 | Train F1: 0.6104
# Dev Loss:   0.4237 | Dev F1:   0.6113
# [INFO] New best model saved! F1 = 0.6113
#
# Epoch 4/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 96.33it/s]
# Train Loss: 0.3853 | Train F1: 0.6330
# Dev Loss:   0.3901 | Dev F1:   0.6143
# [INFO] New best model saved! F1 = 0.6143
#
# Epoch 5/30
# ...
# eval: 100%|██████████| 50/50 [00:00<00:00, 88.48it/s]
# Train Loss: 0.3474 | Train F1: 0.7262
# Dev Loss:   0.3703 | Dev F1:   0.7473
# ...

# %%
# %run test.py -c config/gru.yaml
# Out:
# Vocab size: 1525
# Num labels: 4
# D:\DS\ds201\TH\23520781_lab3\test.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# ## Bài 3

# %%
# %run train_ner.py -c config/bilstm_ner.yaml
# Out:
# Vocab size: 5243
# Num labels: 20
#
# Epoch 1/30
# ...
# eval: 100%|██████████| 63/63 [00:02<00:00, 31.49it/s]
# Train Loss: 0.9739 | Train F1: 0.0107
# Dev   Loss: 0.7247 | Dev   F1: 0.0499
# [SAVE] Best model saved, F1 = 0.0499
#
# Epoch 2/30
# ...
# eval: 100%|██████████| 63/63 [00:02<00:00, 30.82it/s]
# Train Loss: 0.3293 | Train F1: 0.3346
# Dev   Loss: 0.2824 | Dev   F1: 0.5126
# [SAVE] Best model saved, F1 = 0.5126
#
# Epoch 3/30
# ...
# eval: 100%|██████████| 63/63 [00:02<00:00, 29.64it/s]
# Train Loss: 0.1832 | Train F1: 0.5477
# Dev   Loss: 0.2427 | Dev   F1: 0.5265
# [SAVE] Best model saved, F1 = 0.5265
#
# Epoch 4/30
# ...
# eval: 100%|██████████| 63/63 [00:01<00:00, 33.12it/s]
# Train Loss: 0.1345 | Train F1: 0.6268
# Dev   Loss: 0.2309 | Dev   F1: 0.6280
# [SAVE] Best model saved, F1 = 0.6280
#
# Epoch 5/30
# ...
# eval: 100%|██████████| 63/63 [00:01<00:00, 35.45it/s]
# Train Loss: 0.1108 | Train F1: 0.6668
# Dev   Loss: 0.2078 | Dev   F1: 0.6422
# [SAVE] Best model saved, F1 = 0.6422
#
# ...

# %%
# %run test_ner.py
# Out:
# Device: cuda
# Vocab size: 5243
# Num labels: 20
# D:\DS\ds201\TH\23520781_lab3\test_ner.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
